# %%
import pandas as pd

# %%
iris = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Iris.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-82ba647911a4> in <module>
# ----> 1 iris = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Iris.csv')
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
iris = pd.read_csv('https://drive.google.com/file/d/1OGzD3uJQpIuNwZHprwOC4Mk_rv_5bDoJ/view?usp=share_link')

# %%
iris
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="5cv1lhHa3khC96XRAAF87A">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>Iris
# ...

# %%
iris=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-885e0bf1a26b> in <module>
# ----> 1 iris=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")
#
# NameError: name 'pd' is not defined

# %%
iris=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-885e0bf1a26b> in <module>
# ----> 1 iris=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
iris=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Iris.csv")

# %%
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
iris.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris['Id']
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
iris[0:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris.loc[0:2]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris.loc[0:2,'Id':'PetalWidthCm']
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2

# %%
iris.iloc[1:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
iris.iloc[1:5,1:5]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
iris.isnull()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
iris.isna()
# Out:
#         Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0    False          False         False          False         False    False
# 1    False          False         False          False         False    False
# 2    False          False         False          False         False    False
# 3    False          False         False          False         False    False
# 4    False          False         False          False         False    False
# ..     ...            ...           ...            ...           ...      ...
# 145  False          False         False          False         False    False
# 146  False          False         False          False         False    False
# 147  False          False         False          False         False    False
# 148  False          False         False          False         False    False
# 149  False          False         False          False         False    False
#
# [150 rows x 6 columns]

# %%
iris.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
iris.SepalLengthCm.isnull().sum()
# Out:
# 0

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.SepalLengthCm=iris.SepalLengthCm.astype("int")

# %%
iris.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1              5           3.5            1.4           0.2  Iris-setosa
# 1   2              4           3.0            1.4           0.2  Iris-setosa
# 2   3              4           3.2            1.3           0.2  Iris-setosa
# 3   4              4           3.1            1.5           0.2  Iris-setosa
# 4   5              5           3.6            1.4           0.2  Iris-setosa

# %%
x=iris.iloc[:,:4]

# %%
min_max_scaler = preprocessing.MinMaxScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-73f4a2803e61> in <module>
# ----> 1 min_max_scaler = preprocessing.MinMaxScaler()
#
# NameError: name 'preprocessing' is not defined

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1              5           3.5            1.4
# 1      2              4           3.0            1.4
# 2      3              4           3.2            1.3
# 3      4              4           3.1            1.5
# 4      5              5           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146              6           3.0            5.2
# 146  147              6           2.5            5.0
# 147  148              6           3.0            5.2
# 148  149              6           3.4            5.4
# 149  150              5           3.0            5.1
#
# [150 rows x 4 columns]

# %%
x_scaled = min_max_scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-4b42f26022e6> in <module>
# ----> 1 x_scaled = min_max_scaler.fit_transform(x)
#
# NameError: name 'min_max_scaler' is not defined

# %%
df_normalized = pd.DataFrame(x_scaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b1e1c4da5775> in <module>
# ----> 1 df_normalized = pd.DataFrame(x_scaled)
#
# NameError: name 'x_scaled' is not defined

# %%
df_normalized
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-71651907208b> in <module>
# ----> 1 df_normalized
#
# NameError: name 'df_normalized' is not defined

# %%
x_scaled = min_max_scaler.fit_transform(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-4b42f26022e6> in <module>
# ----> 1 x_scaled = min_max_scaler.fit_transform(x)
#
# NameError: name 'min_max_scaler' is not defined

# %%
min_max_scaler = preprocessing.MinMaxScaler()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-73f4a2803e61> in <module>
# ----> 1 min_max_scaler = preprocessing.MinMaxScaler()
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn import preprocessing

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1              5           3.5            1.4           0.2  Iris-setosa
# 1   2              4           3.0            1.4           0.2  Iris-setosa
# 2   3              4           3.2            1.3           0.2  Iris-setosa
# 3   4              4           3.1            1.5           0.2  Iris-setosa
# 4   5              5           3.6            1.4           0.2  Iris-setosa

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x=iris.iloc[:,:4]

# %%
x
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 0      1              5           3.5            1.4
# 1      2              4           3.0            1.4
# 2      3              4           3.2            1.3
# 3      4              4           3.1            1.5
# 4      5              5           3.6            1.4
# ..   ...            ...           ...            ...
# 145  146              6           3.0            5.2
# 146  147              6           2.5            5.0
# 147  148              6           3.0            5.2
# 148  149              6           3.4            5.4
# 149  150              5           3.0            5.1
#
# [150 rows x 4 columns]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#             0         1         2         3
# 0    0.000000  0.333333  0.625000  0.067797
# 1    0.006711  0.000000  0.416667  0.067797
# 2    0.013423  0.000000  0.500000  0.050847
# 3    0.020134  0.000000  0.458333  0.084746
# 4    0.026846  0.333333  0.666667  0.067797
# ..        ...       ...       ...       ...
# 145  0.973154  0.666667  0.416667  0.711864
# 146  0.979866  0.666667  0.208333  0.677966
# 147  0.986577  0.666667  0.416667  0.711864
# 148  0.993289  0.666667  0.583333  0.745763
# 149  1.000000  0.333333  0.416667  0.694915
#
# [150 rows x 4 columns]

# %%
from sklearn import preprocessing

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
iris['Species']= label_encoder.fit_transform(iris['Species'])

# %%
iris['Species'].unique()
# Out:
# array([0, 1, 2])
